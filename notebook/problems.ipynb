# %% [markdown]
# # Descriptive statistics problems

# %% [markdown]
# ### Exercise 1
#
# We will use NumPy to obtain information to describe statistically.
#
# - Generate an array of 100 elements following a normal distribution.
# - Generate an array of 100 elements following a chi-square distribution with 3 degrees of freedom.
# - Calculate the main metrics and statistical measures that best describe the two vectors.

# %%
# TODO


import numpy as np

import statistics as stats

# Generate an array of 100 elements following a normal distribution

normal_dist = np.random.normal(size=100)

# Generate an array of 100 elements following a chi-square distribution with 3 degrees of freedom
chi2_dist = np.random.chisquare(3, size=100)

print(f"Vector Normal: {normal_dist}")
print(f"Chi_Square Vector: {chi2_dist}")


# Media:

import statistics as stats

media_normal = np.mean(normal_dist)
print(f'Mean (average): {media_normal:.2f}')

# Desviación Standar:

std_normal = np.std(normal_dist)
print(f'Standard Desviación: {std_normal:.2f}')

# Varianza:

varianza_normal = np.var(normal_dist)
print(f'Variance: {varianza_normal:.2f}')

# Skewness:

from scipy.stats import skew

skew_normal = skew(normal_dist)


print(f"Normal skewness: {normal_dist}")


# Kurtosis Normal:

from scipy.stats import kurtosis

kurt_normal = kurtosis(normal_dist)


print(f"Kurtosis Normal: {kurt_normal}")

# Datos de Chi:

#Media:

media_chi2 = np.mean(chi2_dist)
print(f'Mean (average): {media_chi2:.2f}')

# Varianza de Chi:

variance_chi2 = np.var(chi2_dist)
print(f'Variance: {variance_chi2:.2f}')

# Moda de Chi:

mode_chi2 = stats.mode(chi2_dist)
print(f'Mode: {mode_chi2}')

# Mediana de Chi:

median_chi2 = np.median(chi2_dist)
print(f'Median: {median_chi2:.2f}')

# Desviación standar de chi:

std_chi2 = np.std(chi2_dist)
print(f'Standard Deviation: {std_chi2:.2f}')

# Skewness:

from scipy.stats import skew

skewness_chi2 = skew(chi2_dist)
print(f'Skewness: {skewness_chi2:.2f}')

# Kurtosis Normal:

from scipy.stats import kurtosis

kurtosis_chi2 =kurtosis(chi2_dist)
print(f'Kurtosis: {kurtosis_chi2:.2f}')
# Out:
# Vector Normal: [-1.66617293 -0.52902383 -0.43791317 -1.27525395  0.84048545 -0.65375966
#   1.27301286 -0.32807316 -1.39132405 -0.81961161  0.99786309 -0.40993226
#  -0.2834256   1.04230991  0.09007985 -1.51126354 -0.38158973  0.68139487
#  -0.42839821 -0.22537237 -0.36726506  0.20198414  1.42311863 -1.0269506
#   0.64273032  0.15882003 -0.95929806 -1.49880761 -2.04804     0.04043426
#   0.41273248 -0.256571    0.69528624 -0.38463609  0.47973952 -0.84247436
#   0.34421933 -0.95533642 -0.9486211  -0.03993524  0.55884357  0.03030103
#  -0.33969093 -0.41713262  1.23653298  0.1646391   0.3797239  -0.75300475
#  -0.5019777  -0.0894572   0.63220638 -0.58525621  0.44720226  0.71906297
#   0.60587288  0.71367041 -0.24414195 -1.64975024 -0.22566811  0.66358301
#   1.69725382 -1.06622989  0.2676529   0.30823102  0.33359716  0.6154568
#  -0.88150516  1.88136177  0.61900689 -0.81628563  0.09847181  0.68710622
#   1.11084251 -0.68593456 -1.16514673 -0.3508439  -0.37045051 -0.31945521
# ...

# %% [markdown]
# ### Exercise 2
#
# Write a Python program to calculate the standard deviation of the following data:
#
# ```py
# data = [4, 2, 5, 8, 6]
# ```

# %%
# TODO

import math

datos_de_muestra= datos

datos = [4, 2, 5, 8, 6]

# Calcular la media de los datos:
mean = sum(data) / len(data)

#calcular la varianza de los datos:
variance = sum((x - mean)**2 for x in datos) / (len(datos) - 1)

# Calcular la desviacion standar de los datos:
std_dev = math.sqrt(variance)

# Imprimir los datos:

print(f"Datos: {datos}")
print("Standard Deviation:", std_dev)
# Out:
# Datos: [4, 2, 5, 8, 6]
# Standard Deviation: 2.23606797749979
